# %%
import pandas as pd
emb = pd.read_parquet("artifacts/embeddings/strategy_embeddings.parquet")
print(emb.shape)
print(emb["date"].min(), emb["date"].max())
print(emb["split"].value_counts(dropna=False))
print(emb["style_label"].value_counts(dropna=False).head(20))
PY
# Out:
# (64, 15)
# 2010-03-31 00:00:00 2010-03-31 00:00:00
# split
# train    64
# Name: count, dtype: int64
# style_label
# <NA>    64
# Name: count, dtype: Int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 print(emb["split"].value_counts(dropna=False))
#       6 print(emb["style_label"].value_counts(dropna=False).head(20))
# ----> 7 PY
#
# NameError: name 'PY' is not defined
